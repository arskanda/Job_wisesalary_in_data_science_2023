# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("jobs_in_data.csv")

# %%
data.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
data.size
# Out:
# 112260

# %%
data.shape
# Out:
# (9355, 12)

# %%
data.isna().sum()
# Out:
# work_year             0
# job_title             0
# job_category          0
# salary_currency       0
# salary                0
# salary_in_usd         0
# employee_residence    0
# experience_level      0
# employment_type       0
# work_setting          0
# company_location      0
# company_size          0
# dtype: int64

# %%
for i in data.columns:
    print(data[i].nunique())
# Out:
# 4
# 125
# 10
# 11
# 1507
# 1786
# 83
# 4
# 4
# 3
# 70
# 3

# %%
plt.figure(figsize=(10,6))
count=data["work_year"].value_counts()
count.plot(kind='bar')
plt.title("Work year dist")
plt.xlabel("work year")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
data["job_title"].value_counts()
# Out:
# Data Engineer                     2195
# Data Scientist                    1989
# Data Analyst                      1388
# Machine Learning Engineer          991
# Applied Scientist                  272
#                                   ...
# Consultant Data Engineer             1
# Sales Data Analyst                   1
# Managing Director Data Science       1
# AWS Data Architect                   1
# Deep Learning Researcher             1
# Name: job_title, Length: 125, dtype: int64

# %%
salary_title = data.groupby('job_title')['salary_in_usd'].mean()

# %%
plt.figure(figsize=(10,6))
salary_title.plot(kind='barh')
# Out:
# <AxesSubplot: ylabel='job_title'>

# %%
data.columns
# Out:
# Index(['work_year', 'job_title', 'job_category', 'salary_currency', 'salary',
#        'salary_in_usd', 'employee_residence', 'experience_level',
#        'employment_type', 'work_setting', 'company_location', 'company_size'],
#       dtype='object')

# %%
exp_level_salary=data.groupby('experience_level')["salary_in_usd"].mean()

# %%
exp_level_salary.plot(kind = 'bar')
# Out:
# <AxesSubplot: xlabel='experience_level'>

# %%
salary_based_on_expandworksett=data.groupby(["experience_level","work_setting"])["salary_in_usd"].mean()

# %%
salary_based_on_expandworksett.plot(kind = 'barh')
# Out:
# <AxesSubplot: ylabel='experience_level,work_setting'>

# %%
data.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
data.drop('salary',axis=1)
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary_in_usd employee_residence experience_level  \
# ...

# %%
data=data.drop('salary_currency',axis=1)

# %%
data.head(5)
# Out:
#    work_year             job_title                    job_category  salary  \
# 0       2023  Data DevOps Engineer                Data Engineering   88000
# 1       2023        Data Architect  Data Architecture and Modeling  186000
# 2       2023        Data Architect  Data Architecture and Modeling   81800
# 3       2023        Data Scientist       Data Science and Research  212000
# 4       2023        Data Scientist       Data Science and Research   93300
#
#    salary_in_usd employee_residence experience_level employment_type  \
# 0          95012            Germany        Mid-level       Full-time
# 1         186000      United States           Senior       Full-time
# 2          81800      United States           Senior       Full-time
# 3         212000      United States           Senior       Full-time
# 4          93300      United States           Senior       Full-time
#
#   work_setting company_location company_size
# 0       Hybrid          Germany            L
# ...

# %%
x=data.drop('salary_in_usd',axis=1)
y=data['salary_in_usd']

# %%
x.head()
x_cat=x.select_dtypes(include=np.object_)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in x_cat.columns:
    x[i]=le.fit_transform(x_cat[i])

# %%
x
# Out:
#       work_year  job_title  job_category  salary  employee_residence  \
# 0          2023         42             4   88000                  29
# 1          2023         41             3  186000                  80
# 2          2023         41             3   81800                  80
# 3          2023         69             7  212000                  80
# 4          2023         69             7   93300                  80
# ...         ...        ...           ...     ...                 ...
# 9350       2021         71             5  165000                  80
# 9351       2020         69             7  412000                  80
# 9352       2021        114             7  151000                  80
# 9353       2020         69             7  105000                  80
# 9354       2020         21             2  100000                  80
#
#       experience_level  employment_type  work_setting  company_location  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=37)

# %%
from sklearn.linear_model import LinearRegression
le=LinearRegression()
le.fit(x_train,y_train)
y_pred_test=le.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
print(le.score(x_train,y_train))
print(le.score(x_test,y_test))
# Out:
# 0.9876620766950859
# 0.9729380758798674

# %%
x
# Out:
#       work_year  job_title  job_category  salary  employee_residence  \
# 0          2023         42             4   88000                  29
# 1          2023         41             3  186000                  80
# 2          2023         41             3   81800                  80
# 3          2023         69             7  212000                  80
# 4          2023         69             7   93300                  80
# ...         ...        ...           ...     ...                 ...
# 9350       2021         71             5  165000                  80
# 9351       2020         69             7  412000                  80
# 9352       2021        114             7  151000                  80
# 9353       2020         69             7  105000                  80
# 9354       2020         21             2  100000                  80
#
#       experience_level  employment_type  work_setting  company_location  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()
x_mm=mm.fit_transform(x)
x=pd.DataFrame(x_mm,columns=x.columns)
x
# Out:
#       work_year  job_title  job_category    salary  employee_residence  \
# 0      1.000000   0.338710      0.444444  0.169725            0.353659
# 1      1.000000   0.330645      0.333333  0.394495            0.975610
# 2      1.000000   0.330645      0.333333  0.155505            0.975610
# 3      1.000000   0.556452      0.777778  0.454128            0.975610
# 4      1.000000   0.556452      0.777778  0.181881            0.975610
# ...         ...        ...           ...       ...                 ...
# 9350   0.333333   0.572581      0.555556  0.346330            0.975610
# 9351   0.000000   0.556452      0.777778  0.912844            0.975610
# 9352   0.333333   0.919355      0.777778  0.314220            0.975610
# 9353   0.000000   0.556452      0.777778  0.208716            0.975610
# 9354   0.000000   0.169355      0.222222  0.197248            0.975610
#
#       experience_level  employment_type  work_setting  company_location  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=37)

# %%
from sklearn.linear_model import LinearRegression
le=LinearRegression()
le.fit(x_train,y_train)
y_pred_test=le.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
print(le.score(x_train,y_train))
print(le.score(x_test,y_test))
# Out:
# 0.9876620766950858
# 0.9729380758798674

# %%
from sklearn.ensemble import RandomForestRegressor
rr=RandomForestRegressor()

# %%
rr.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_test=rr.predict(x_test)

# %%
rr.score(x_train,y_train)
# Out:
# 0.9984796796842667

# %%
rr.score(x_test,y_test)
# Out:
# 0.9765033553692811
